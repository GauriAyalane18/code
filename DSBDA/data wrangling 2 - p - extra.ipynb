# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/home/student/Downloads/A2.csv')
data.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df=pd.DataFrame(data) #prints the data in the table format
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
data = pd.read_csv('/home/student/Downloads/A2.csv')
df=pd.DataFrame(data)
df.isnull()
# Out:
#       Roll No   Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0       False  False      False      False      False      False       False
# 1       False  False      False      False      False       True       False
# 2       False  False      False      False      False      False       False
# 3       False  False      False      False       True      False       False
# 4       False  False      False      False      False      False       False
# ...       ...    ...        ...        ...        ...        ...         ...
# 996     False  False      False      False      False      False       False
# 997     False  False      False      False      False      False       False
# 998     False  False      False      False      False      False       False
# 999     False  False      False      False      False      False       False
# 1000    False  False      False      False      False      False       False
#
# [1001 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB

# %%
pd.notnull(data)
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True      False        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True      False       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
pd.notnull(df)
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True      False        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True      False       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
df.fillna(0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.ffill()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.bfill()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
data = pd.read_csv('/home/student/Downloads/A2.csv')
df=pd.DataFrame(data)
df.fillna({"Subject 1":85},inplace=True)
df.fillna({"Subject 2	":95},inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
data = pd.read_csv('/home/student/Downloads/A2.csv')
df=pd.DataFrame(data)
# df["Subject 1"].fillna(df["Subject 1"].mean(),inplace=True)
# df["Subject 2"].fillna(df["Subject 2"].mean(),inplace=True)
df['Subject 1'] = df['Subject 1'].fillna(df['Subject 1'].mean())
df['Subject 2'] = df['Subject 2'].fillna(df['Subject 2'].mean())
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
nc=["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]
for c in nc:
    #df[c].fillna(df[c].mean(),inplace=True)
    df.fillna({c: df[c].mean()}, inplace=True)
    
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df=df.replace(to_replace=np.nan,value=85)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df=df.apply(pd.to_numeric,errors='coerce')
df = df.interpolate(method='linear', limit_direction='forward')
df
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0           1   NaN        100         62       73.0       92.0          96
# 1           2   NaN         72         97       82.0       95.5          78
# 2           3   NaN        100         88       71.0       99.0         -94
# 3           4   NaN         72         99       77.5       84.0          86
# 4           5   NaN         97         70       84.0       70.0          86
# ...       ...   ...        ...        ...        ...        ...         ...
# 996       997   NaN         88         68       84.0       66.0          98
# 997       998   NaN         61         96       62.0       84.0          83
# 998       999   NaN         72         76       90.0       72.0          90
# 999      1000   NaN         68         87      100.0       76.0          79
# 1000        1   NaN        100         62       73.0       92.0          96
#
# [1001 rows x 7 columns]

# %%
df=pd.DataFrame(data)
df=df.dropna()
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
data = pd.read_csv('/home/student/Downloads/A2.csv')
df=pd.DataFrame(data)
df=df[df[["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]]<0]
df
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 3         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [1001 rows x 7 columns]

# %%
df[df[["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]]<0]=df[df[["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]]<0].clip(lower=0)
df
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN         0.0
# 3         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [1001 rows x 7 columns]

# %%
df=pd.DataFrame(data)
df.drop_duplicates(inplace=True)
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 1          2     Student_2         72         97       82.0        NaN
# 2          3     Student_3        100         88       71.0       99.0
# 3          4     Student_4         72         99        NaN       84.0
# 4          5     Student_5         97         70       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 1            78
# 2           -94
# 3            86
# 4            86
# ...

# %%
df=pd.DataFrame(data)
df=df.dropna(how='all',inplace=True)
df

# %%
df=pd.DataFrame(data)
df.dropna(axis=1)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Attendance
# 0           1     Student_1        100         62          96
# 1           2     Student_2         72         97          78
# 2           3     Student_3        100         88         -94
# 3           4     Student_4         72         99          86
# 4           5     Student_5         97         70          86
# ...       ...           ...        ...        ...         ...
# 996       997   Student_997         88         68          98
# 997       998   Student_998         61         96          83
# 998       999   Student_999         72         76          90
# 999      1000  Student_1000         68         87          79
# 1000        1     Student_1        100         62          96
#
# [1001 rows x 5 columns]

# %%
df=pd.DataFrame(data)
df.dropna(axis=0)  #axis=0 rows and axis=1 columns
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df=pd.DataFrame(data)
df.dropna(axis=0,how='any')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
nc=["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]
for c in nc:
    #df[c].fillna(df[c].mean(),inplace=True)
    df.fillna({c: df[c].mean()}, inplace=True)
    sns.boxplot(x=df[c])
    plt.title(f'box plot of {c}')
    plt.show()

# %%
for c in nc:
    Q1=df[c].quantile(0.25)
    Q3=df[c].quantile(0.75)
    IQR=Q3-Q1
    lowerbound=Q1-1.5*IQR
    upperbound=Q3+1.5*IQR
    df[c]=np.where((df[c]<lowerbound)|(df[c]>upperbound),df[c].median(),df[c])
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1      100.0       62.0      73.00     92.000
# 1           2     Student_2       72.0       97.0      82.00     80.545
# 2           3     Student_3      100.0       88.0      71.00     99.000
# 3           4     Student_4       72.0       99.0      79.89     84.000
# 4           5     Student_5       97.0       70.0      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997       88.0       68.0      84.00     66.000
# 997       998   Student_998       61.0       96.0      62.00     84.000
# 998       999   Student_999       72.0       76.0      90.00     72.000
# 999      1000  Student_1000       68.0       87.0     100.00     76.000
# 1000        1     Student_1      100.0       62.0      73.00     92.000
#
#       Attendance
# 0           96.0
# 1           78.0
# 2           86.0
# 3           86.0
# ...

# %%
data = pd.read_csv('/home/student/Downloads/A2.csv')
df=pd.DataFrame(data)

# %%
from scipy import stats
z=np.abs(stats.zscore(df['Subject 4']))
z
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 996    NaN
# 997    NaN
# 998    NaN
# 999    NaN
# 1000   NaN
# Name: Subject 4, Length: 1001, dtype: float64

# %%
threshold=1
print(np.where(z>1))
# Out:
# (array([], dtype=int64),)

# %%
df['log_Attendance']=np.log1p(df['Attendance'])
df
# Out:
# /home/student/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# ...

# %%
from scipy import stats
data = pd.read_csv('/home/student/Downloads/A2.csv')
df = pd.DataFrame(data)
#skewness = df.skew()
nc=["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]
for col in nc:
    stat, p_value = stats.shapiro(data['Subject 3'].dropna())  
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...
