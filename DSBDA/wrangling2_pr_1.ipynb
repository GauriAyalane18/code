# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df.shape
# Out:
# (1001, 7)

# %%
df.describe()
# Out:
#            Roll No    Subject 1    Subject 2    Subject 3    Subject 4  \
# count  1001.000000  1001.000000  1001.000000  1000.000000  1000.000000
# mean    500.000999    79.233766    80.064935    79.890000    80.545000
# std     289.106384    12.085913    11.904318    11.539457    11.793688
# min       1.000000    60.000000    60.000000    50.000000    40.000000
# 25%     250.000000    69.000000    70.000000    70.000000    71.000000
# 50%     500.000000    79.000000    80.000000    80.000000    81.000000
# 75%     750.000000    90.000000    91.000000    90.000000    91.000000
# max    1000.000000   100.000000   100.000000   100.000000   100.000000
#
#         Attendance
# count  1001.000000
# mean     85.416583
# std      10.277319
# min     -94.000000
# 25%      79.000000
# 50%      86.000000
# 75%      93.000000
# max     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df=df.fillna(value=0)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=df.fillna(method='ffill')
# Out:
# C:\Users\Gauri\AppData\Local\Temp\ipykernel_8652\1718901248.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='ffill')

# %%
df=df.fillna(method='bfill')
df
# Out:
# C:\Users\Gauri\AppData\Local\Temp\ipykernel_8652\2721427092.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='bfill')
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# ...

# %%
df.fillna({"Subject 3":df["Subject 3"].mean()}, inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df.fillna({"Subject 3": df["Subject 3"].median()}, inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       80.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df=df.replace(to_replace=np.nan,value=80)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       80.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       80.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df=df.apply(pd.to_numeric,errors='coerce')
df.interpolate(method='linear',limit_direction='forward')
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0           1   NaN        100         62       73.0       92.0          96
# 1           2   NaN         72         97       82.0       95.5          78
# 2           3   NaN        100         88       71.0       99.0         -94
# 3           4   NaN         72         99       77.5       84.0          86
# 4           5   NaN         97         70       84.0       70.0          86
# ...       ...   ...        ...        ...        ...        ...         ...
# 996       997   NaN         88         68       84.0       66.0          98
# 997       998   NaN         61         96       62.0       84.0          83
# 998       999   NaN         72         76       90.0       72.0          90
# 999      1000   NaN         68         87      100.0       76.0          79
# 1000        1   NaN        100         62       73.0       92.0          96
#
# [1001 rows x 7 columns]

# %%
df=df.dropna(how='any')

# %%
df=df.dropna(how='all')
df
# Out:
# Empty DataFrame
# Columns: [Roll No, Name, Subject 1, Subject 2, Subject 3, Subject 4, Attendance]
# Index: []

# %%
df=df.dropna(how='any',axis=0)
df
# Out:
# Empty DataFrame
# Columns: [Roll No, Name, Subject 1, Subject 2, Subject 3, Subject 4, Attendance]
# Index: []

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df[df[["Subject 1","Subject 2","Subject 3","Subject 4","Attendance"]]<0]
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 3         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [1001 rows x 7 columns]

# %%
df=df.drop_duplicates(inplace=True)
df

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
nc=['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']
for c in nc:
  #plt.subplot(1,3,1)
  sns.boxplot(x=df[c])
  plt.title("Boxplot")
  plt.show()

# %%
for c in nc:
  q1=df[c].quantile(0.25)
  q3=df[c].quantile(0.75)
  iqr=q3-q1
print(iqr)
# Out:
# 14.0

# %%
df = pd.read_csv('C:/Users/Gauri/Downloads/A2.csv')
df.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
from scipy import stats
z=np.abs(stats.zscore(df['Subject 2']))
z
# Out:
# array([1.51826974, 1.42330966, 0.66690353, ..., 0.34163798, 0.5828584 ,
#        1.51826974], shape=(1001,))
